# %%
#Task-1: Work on different Regex Example
#Task -2 : Iterators in Python

# %%
a = 10

# %%
if 20 == 20:
    print("Correct")

# %%
i = 1
while i < 6:
    i += 1
print(i)

# %%
if 20 == 20:
    break
    print("bshsb")

# %%
i = 1
while i < 6:
  print(i)
  if i == 3:
    break
  i += 1
# Out:
# 1
# 2
# 3

# %%
i = 0
while i < 6:
  i += 1
  if i == 3:
    continue
  print(i)
# Out:
# 1
# 2
# 4
# 5
# 6

# %%
if False:
    print("bscbs")
else:
    print("Hello")

# %%
i = 1
while i < 6:
  print(i)
  i += 1
  if i == 3: 
    break
else:
  print("i is no longer less than 6")
# Out:
# 1
# 2

# %%
for(i=0;i<20;i++)

# %%
phone = {"Iphone", "Samsung", "Pixel", "MI"}
it = iter(phone)
print(it)
# Out:
# <set_iterator object at 0x000001E347863540>

# %%
next
X001 : Iphone
next
X001 : Samsung
next
X001 : Pixel

# %%
phone = {"Iphone", "Samsung", "Pixel", "MI"}
it = iter(phone)
print(next(it))
# Out:
# Pixel

# %%
next(it)
# Out:
# 'MI'

# %%
next(it)
# Out:
# 'Iphone'

# %%
next(it)
# Out:
# 'Samsung'

# %%
next(it)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 next(it)
#
# StopIteration:

# %%
for i in phone:
    print(i)

# %%
phone = ['Iphone', 'Samsung', 'Pixel', 'MI']
for x in phone:
  print(x)
  if x == "Pixel":
    break
# Out:
# Iphone
# Samsung
# Pixel

# %%
phone = ['Iphone', 'Samsung', 'Pixel', 'MI']
for x in phone:
  if x == "Pixel":
    break
  print(x)
# Out:
# Iphone
# Samsung

# %%
phone = ['Iphone', 'Samsung', 'Pixel', 'MI']
for x in phone:
  print(x)
  if x == "Pixel":
    continue
# Out:
# Iphone
# Samsung
# Pixel
# MI

# %%
phone = ['Iphone', 'Samsung', 'Pixel', 'MI']
print(id(phone))
print(id(phone[0]))
# Out:
# 2075723041280
# 2075689308192

# %%
phone[1:3]

# %%
range(0,6,2)

# %%
for x in range(20):
    if x%2 == 0:
        print(x, end = " ")

# %%
for x in range(2, 6):
  print(x, end=" ")

# %%
for x in range(2, 30, 3):
  print(x,end=" ")

# %%
for x in range(6):
  print(x)
else:
  print("Finally finished!")
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# Finally finished!

# %%
for x in range(6):
  if x == 3: break
  print(x)
else:
  print("Finally finished!")
# Out:
# 0
# 1
# 2

# %%
#

# %%
*
**
***
****
*****
# Out:
#   Cell In[33], line 1
#     *
#      ^
# SyntaxError: invalid syntax
